# %% [markdown]
#  main  ←───────────┐
#    ↑               │
#  hotfix/xxx        │
#    ↑               │
#  release/xxx  ─────┤→ (merge vào main + develop)
#    ↑               │
#  develop  ←────────┘
#    ↑
#  feature/login
#  feature/home
